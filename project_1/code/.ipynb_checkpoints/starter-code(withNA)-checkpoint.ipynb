# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** The project aims to identify if there is any corelation between standardized tests performance and the poverty reate in California state in the U.S

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](../data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](../data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](../data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](../data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](../data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2019_ca.csv`](../data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](../data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`act_2019_ca.csv`](../data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2019_ca.csv`](../data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`crime-rates-by-county-2019.xlsx`](../data/crime-rates-by-county-2019.xlsx): Crime rates in California
# * [`poverty-across-california-2017-19.xlsx`](../data/poverty-across-california-2017-19.xlsx): Poverty in California

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#function to calculate mean
def mean_value(list_of_num):
    '''Return mean value of the input list of numbers'''
    sum_of_values = 0
    num_of_values = 0
    for num in list_of_num:
        sum_of_values += num
        num_of_values += 1
    return sum_of_values / num_of_values

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#function to calculate std deviation
def std_dev(list_of_num):
    '''return the standard deviation of the input list of numbers'''
    sum_of_sqaures = 0
    num_of_values = 0
    for num in list_of_num:
        #calling previously defined mean_value() function to compute sum of squares
        sum_of_sqaures  += (num-mean_value(list_of_num)) ** 2
        num_of_values += 1
    return (sum_of_sqaures/num_of_values) ** 0.5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#function to convert string with percentage to float 
def string_to_float(string):
    '''return float value of the input string with percentage format (e.g.50%)'''
    return float(string[:-1]) / 100

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import libraries:
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#Import .csv to dataframe
sat_2019_ca = pd.read_csv('../data/sat_2019_ca.csv')
act_2019_ca = pd.read_csv('../data/act_2019_ca.csv')
crime = pd.read_excel('../data/crime-rates-by-county-2019.xlsx', header=3)
poverty = pd.read_excel('../data/poverty-across-california-2017-19.xlsx',
                        sheet_name='Counties', 
                        header=[0,1], 
                        index_col= None)

# %% [markdown]
# ### Step 1. Inspect the first 5 rows of dataframe

# %%
sat_2019_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
act_2019_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
crime.head()
# Out:
#       County  Population      Violent    Murder        Rape     Robbery  \
# 0    Alameda   1664783.0   584.700829  5.766517   42.167658  295.293741
# 1     Alpine      1149.0  1131.418625  0.000000  174.064404    0.000000
# 2     Amador     37820.0   290.851401  2.644104   21.152829   23.796933
# 3      Butte    221521.0   462.258657  3.159971   81.256405   75.387886
# 4  Calaveras     45085.0   321.614728  2.218033   75.413109   19.962293
#
#    Aggrevated assault     Property     Burglary  Vehicle theft  Larceny theft
# 0          241.472913  4008.390283   391.402363     616.717014    3000.270906
# 1          957.354221  2785.030461  1131.418625     348.128808    1305.483029
# 2          243.257536  1771.549445   470.650449      97.831835    1203.067160
# 3          302.454395  2402.481029   501.532586     391.836440    1509.112003
# 4          224.021293  1858.711323   658.755684     153.044250    1046.911390

# %%
poverty.head()
# Out:
#               County                                       County group  \
#   Unnamed: 0_level_1                                 Unnamed: 1_level_1
# 0            Alameda                                            Alameda
# 1             Alpine  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
# 2             Amador  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
# 3              Butte                                              Butte
# 4          Calaveras  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
#
#   CPM poverty                                                             \
#          Rate Rate margin of error (% pt)  Number Number margin of error
# 0    0.140840                    0.688138  229400                  11200
# 1    0.131689                    2.681757   23700                   4800
# 2    0.131689                    2.681757   23700                   4800
# 3    0.178642                    1.951575   39000                   4200
# ...

# %% [markdown]
# ### Step 2. Check for missing values in dataframe

# %%
sat_2019_ca.isna().sum()
# Out:
# CDS                         1
# CCode                       1
# CDCode                      1
# SCode                       1
# RType                       1
# SName                     598
# DName                      59
# CName                       1
# Enroll12                    1
# NumTSTTakr12                1
# NumERWBenchmark12         276
# PctERWBenchmark12         276
# NumMathBenchmark12        276
# PctMathBenchmark12        276
# Enroll11                    1
# NumTSTTakr11                1
# NumERWBenchmark11         311
# PctERWBenchmark11         311
# NumMathBenchmark11        311
# PctMathBenchmark11        311
# TotNumBothBenchmark12     276
# PctBothBenchmark12        276
# TotNumBothBenchmark11     311
# PctBothBenchmark11        311
# Year                        1
# Unnamed: 25              2580
# dtype: int64

# %%
act_2019_ca.isna().sum()
# Out:
# CDS               1
# CCode             1
# CDCode            1
# SCode           523
# RType             1
# SName           581
# DName            59
# CName             1
# Enroll12          1
# NumTstTakr        1
# AvgScrRead      357
# AvgScrEng       357
# AvgScrMath      357
# AvgScrSci       357
# NumGE21         357
# PctGE21         357
# Year              1
# Unnamed: 17    2310
# dtype: int64

# %%
crime.isna().sum()
# Out:
# County                1
# Population            1
# Violent               1
# Murder                1
# Rape                  1
# Robbery               1
# Aggrevated assault    1
# Property              1
# Burglary              1
# Vehicle theft         1
# Larceny theft         1
# dtype: int64

# %%
poverty.isna().sum()
# Out:
# County                                         Unnamed: 0_level_1              0
# County group                                   Unnamed: 1_level_1              0
# CPM poverty                                    Rate                            0
#                                                Rate margin of error (% pt)     0
#                                                Number                          0
#                                                Number margin of error          0
# Official poverty                               Rate                            0
#                                                Rate margin of error (% pt)     0
# CPM child poverty                              Rate                            0
#                                                Rate margin of error (% pt)     0
# CPM poverty threshold, family of 4 that rents  ($)                             0
# Increase in poverty without safety net         Increase (% pt)                 0
# ...

# %% [markdown]
# ### Step 3. Issues identified with the dataset

# %%
sat_2019_ca.describe(include='all')
# Out:
#                  CDS        CCode        CDCode         SCode RType  \
# count   2.579000e+03  2579.000000  2.579000e+03  2.579000e+03  2579
# unique           NaN          NaN           NaN           NaN     4
# top              NaN          NaN           NaN           NaN     S
# freq             NaN          NaN           NaN           NaN  1981
# mean    2.915139e+13    28.519581  2.915138e+06  1.544913e+06   NaN
# std     1.428328e+13    14.258173  1.428327e+06  1.812049e+06   NaN
# min     0.000000e+00     0.000000  0.000000e+00  0.000000e+00   NaN
# 25%     1.964725e+13    19.000000  1.964725e+06  1.025080e+05   NaN
# 50%     3.066597e+13    30.000000  3.066597e+06  1.377860e+05   NaN
# 75%     3.777103e+13    37.000000  3.777103e+06  3.037422e+06   NaN
# max     5.872770e+13    58.000000  5.872769e+06  6.120893e+06   NaN
#
#                        SName                DName        CName       Enroll12  \
# ...

# %%
act_2019_ca.describe(include='all')
# Out:
#                  CDS        CCode        CDCode         SCode RType  \
# count   2.309000e+03  2309.000000  2.309000e+03  1.787000e+03  2309
# unique           NaN          NaN           NaN           NaN     4
# top              NaN          NaN           NaN           NaN     S
# freq             NaN          NaN           NaN           NaN  1728
# mean    2.929718e+13    28.666522  2.855616e+06  1.902681e+06   NaN
# std     1.444996e+13    14.425498  1.492574e+06  1.838954e+06   NaN
# min     0.000000e+00     0.000000  0.000000e+00  0.000000e+00   NaN
# 25%     1.964725e+13    19.000000  1.964519e+06  1.254385e+05   NaN
# 50%     3.066647e+13    30.000000  3.066548e+06  1.930288e+06   NaN
# 75%     3.868478e+13    38.000000  3.777032e+06  3.435674e+06   NaN
# max     5.872770e+13    58.000000  5.872769e+06  6.120893e+06   NaN
#
#                       SName                DName        CName       Enroll12  \
# ...

# %%
crime.describe(include='all')
# Out:
#          County    Population      Violent     Murder        Rape     Robbery  \
# count        59  5.900000e+01    59.000000  59.000000   59.000000   59.000000
# unique       59           NaN          NaN        NaN         NaN         NaN
# top     Alameda           NaN          NaN        NaN         NaN         NaN
# freq          1           NaN          NaN        NaN         NaN         NaN
# mean        NaN  1.345606e+06   418.716356   3.836516   47.253109   76.963178
# std         NaN  5.287521e+06   184.376685   2.975429   28.962759   64.616574
# min         NaN  1.149000e+03    31.152648   0.000000    0.000000    0.000000
# 25%         NaN  4.980850e+04   311.016278   1.853600   30.867307   37.602983
# 50%         NaN  1.900180e+05   405.677064   3.399017   41.506693   63.159531
# 75%         NaN  7.698935e+05   500.905195   4.929872   51.164647   92.173522
# max         NaN  3.969538e+07  1131.418625  14.665982  174.064404  356.108330
#
# ...

# %%
poverty.describe(include='all')
# Out:
#                    County                                       County group  \
#        Unnamed: 0_level_1                                 Unnamed: 1_level_1
# count                  58                                                 58
# unique                 58                                                 41
# top               Alameda  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
# freq                    1                                                  7
# mean                  NaN                                                NaN
# std                   NaN                                                NaN
# min                   NaN                                                NaN
# 25%                   NaN                                                NaN
# 50%                   NaN                                                NaN
# 75%                   NaN                                                NaN
# ...

# %% [markdown]
# #### Dataframe:  `sat_2019_ca`
#
#
# | S/N| Issues Identified| Cleaning Required |
# |----|:-----------------|:----------------- |
# |1. | Multiple missing values (e.g. NaN or *)| Review the data is required in analysis. <br /> Drop data if not required |
# |2. | Additional column 'Unnamed:25'  | Drop column     |
#
#
#
# #### Dataframe: `act_2019_ca`
#
# | S/N| Issues Identified| Cleaning Required |
# |--|----------- | ----------- |
# |1. | Multiple missing values (e.g. NaN or *)| Review the data is required in analysis. <br /> Drop data if not required |
# |2. | Additional column 'Unnamed:17'| Drop column|
#
# #### Dataframe: `crime`
#
# | S/N| Issues Identified| Cleaning Required |
# |--|----------- | ----------- |
# |1. | Empty row (index 58)| Drop row |
#
#
# #### Dataframe: `poverty`
# | S/N| Issues Identified| Cleaning Required |
# |--|----------- | ----------- |
# |1. | Missing values in "Increase in poverty without CalEITC and YCTC" column| Drop column |

# %%
sat_2019_ca[sat_2019_ca['CDS'].isna()]
# Out:
#       CDS  CCode  CDCode  SCode RType SName DName CName  Enroll12  \
# 2579  NaN    NaN     NaN    NaN   NaN   NaN   NaN   NaN       NaN
#
#       NumTSTTakr12  ... NumERWBenchmark11 PctERWBenchmark11  \
# 2579           NaN  ...               NaN               NaN
#
#      NumMathBenchmark11 PctMathBenchmark11  TotNumBothBenchmark12  \
# 2579                NaN                NaN                    NaN
#
#       PctBothBenchmark12 TotNumBothBenchmark11 PctBothBenchmark11 Year  \
# 2579                 NaN                   NaN                NaN  NaN
#
#      Unnamed: 25
# 2579         NaN
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Step 4. Fix any errors you identified in steps 2-3.

# %% [markdown]
# #### Cleaning on Dataframe:  `sat_2019_ca`

# %%
#Analysis will be based on county level, drop district and schoool level data.
sat_2019_ca = sat_2019_ca[sat_2019_ca['RType']=='C']

# %%
#Keep information grade 12 students, drop other irrelavent information e.g. grade 11 students.
sat_2019_ca = sat_2019_ca[['RType',
                           'CName',
                           'Enroll12',
                           'NumTSTTakr12',
                           'NumERWBenchmark12', 
                           'PctERWBenchmark12',
                           'NumMathBenchmark12',
                           'PctMathBenchmark12',
                           'TotNumBothBenchmark12',
                           'PctBothBenchmark12']].reset_index(drop=True)

# %%
#Replace * with NaN
sat_2019_ca.replace('*', np.nan, inplace=True)

# %%
sat_2019_ca.isna().sum()
# Out:
# RType                    0
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        3
# PctERWBenchmark12        3
# NumMathBenchmark12       3
# PctMathBenchmark12       3
# TotNumBothBenchmark12    3
# PctBothBenchmark12       3
# dtype: int64

# %%
sat_2019_ca.dropna(inplace=True)

# %%
sat_2019_ca.isna().sum()
# Out:
# RType                    0
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# dtype: int64

# %%
sat_2019_ca.head()
# Out:
#   RType        CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0     C    El Dorado    2226.0         604.0               547
# 1     C  Los Angeles  114618.0       48676.0             30081
# 2     C       Madera    2352.0         442.0               277
# 3     C         Yolo    2299.0         759.0               586
# 4     C         Kern   14229.0        3793.0              2334
#
#   PctERWBenchmark12 NumMathBenchmark12 PctMathBenchmark12  \
# 0             90.56                458              75.83
# 1             61.80              19791              40.66
# 2             62.67                136              30.77
# 3             77.21                464              61.13
# 4             61.53               1481              39.05
#
#   TotNumBothBenchmark12 PctBothBenchmark12
# 0                   442              73.18
# 1                 18555              38.12
# 2                   127              28.73
# 3                   443              58.37
# ...

# %% [markdown]
# #### Cleaning on Dataframe:  `act_2019_ca`

# %%
#Analysis will be based on county level, drop district and schoool level data.
act_2019_ca = act_2019_ca[act_2019_ca['RType']=='C']

# %%
#Keep information grade 12 students, drop other irrelavent information e.g. grade 11 students.
act_2019_ca = act_2019_ca[['RType',
                           'CName',
                           'Enroll12',
                           'NumTstTakr',
                           'AvgScrRead',
                           'AvgScrEng',
                           'AvgScrMath',
                           'AvgScrSci',
                           'NumGE21',
                           'PctGE21']].reset_index(drop=True)

# %%
#Replace * with NaN
act_2019_ca.replace('*', np.nan, inplace=True)

# %%
act_2019_ca.head()
# Out:
#   RType        CName  Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath  \
# 0     C   Sacramento   19540.0      3065.0         21        20         21
# 1     C  San Joaquin   11778.0      1348.0         22        21         21
# 2     C         Kern   14229.0      1257.0         21        20         20
# 3     C       Shasta    2161.0       173.0         26        24         24
# 4     C       Sutter    1827.0       196.0         23        22         22
#
#   AvgScrSci NumGE21 PctGE21
# 0        21    1526   49.79
# 1        21     693   51.41
# 2        20     544   43.28
# 3        24     131   75.72
# 4        22     117   59.69

# %% [markdown]
# #### Cleaning on Dataframe:  `crime`

# %%
#Drop empty row (index 58) and row on statewide data (index 59)
crime.drop([58,59], inplace=True)

# %%
crime.tail()
# Out:
#       County  Population     Violent    Murder        Rape    Robbery  \
# 53    Tulare    476588.0  355.023626  4.196497   40.706019  81.621862
# 54  Tuolumne     54532.0  357.588205  3.667571  124.697425  23.839214
# 55   Ventura    846050.0  216.299273  2.836712   27.421547  62.289463
# 56      Yolo    220896.0  288.370998  2.716210   39.385050  79.675503
# 57      Yuba     77342.0  421.504487  9.050710   53.011300  78.870471
#
#     Aggrevated assault     Property    Burglary  Vehicle theft  Larceny theft
# 53          228.499249  2229.388906  424.895297     387.126827    1417.366782
# 54          205.383995  1969.485806  687.669625     185.212352    1096.603829
# 55          123.751551  1493.292359  230.010047     145.854264    1117.428048
# 56          166.594234  3007.750254  418.749095     265.735912    2323.265247
# 57          280.572005  2384.215562  523.648212     614.155310    1246.412040

# %% [markdown]
# #### Cleaning on Dataframe:  `poverty`

# %%
poverty.head()
# Out:
#               County                                       County group  \
#   Unnamed: 0_level_1                                 Unnamed: 1_level_1
# 0            Alameda                                            Alameda
# 1             Alpine  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
# 2             Amador  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
# 3              Butte                                              Butte
# 4          Calaveras  Alpine/Amador/Calaveras/Inyo/Mariposa/Mono/Tuo...
#
#   CPM poverty                                                             \
#          Rate Rate margin of error (% pt)  Number Number margin of error
# 0    0.140840                    0.688138  229400                  11200
# 1    0.131689                    2.681757   23700                   4800
# 2    0.131689                    2.681757   23700                   4800
# 3    0.178642                    1.951575   39000                   4200
# ...

# %%
poverty = poverty[['County', 'Official poverty ']]

# %%
poverty.columns = ['county', 'poverty_rate', 'rate_margin_of_error(%)']

# %%
poverty.head()
# Out:
#       county  poverty_rate  rate_margin_of_error(%)
# 0    Alameda      0.082354                 0.640117
# 1     Alpine      0.109303                 2.230296
# 2     Amador      0.109303                 2.230296
# 3      Butte      0.167177                 2.034078
# 4  Calaveras      0.109303                 2.230296

# %% [markdown]
# ### Step 5. Display the data types of each feature.

# %%
sat_2019_ca.dtypes
# Out:
# RType                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# dtype: object

# %%
act_2019_ca.dtypes
# Out:
# RType          object
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead     object
# AvgScrEng      object
# AvgScrMath     object
# AvgScrSci      object
# NumGE21        object
# PctGE21        object
# dtype: object

# %%
crime.dtypes
# Out:
# County                 object
# Population            float64
# Violent               float64
# Murder                float64
# Rape                  float64
# Robbery               float64
# Aggrevated assault    float64
# Property              float64
# Burglary              float64
# Vehicle theft         float64
# Larceny theft         float64
# dtype: object

# %%
poverty.dtypes
# Out:
# county                      object
# poverty_rate               float64
# rate_margin_of_error(%)    float64
# dtype: object

# %% [markdown]
# ### Step 6. Fix any incorrect data types found in step 5.

# %%
#change columns to numeric type
columns = ['NumERWBenchmark12',
           'PctERWBenchmark12',
           'NumMathBenchmark12',
           'PctMathBenchmark12',
           'TotNumBothBenchmark12',
           'PctBothBenchmark12']
sat_2019_ca[columns] = sat_2019_ca[columns].apply(pd.to_numeric, axis=1)

# %%
sat_2019_ca.dtypes
# Out:
# RType                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12        float64
# PctERWBenchmark12        float64
# NumMathBenchmark12       float64
# PctMathBenchmark12       float64
# TotNumBothBenchmark12    float64
# PctBothBenchmark12       float64
# dtype: object

# %%
#change columns to numeric type
columns = ['NumTstTakr',
           'AvgScrRead',
           'AvgScrEng',
           'AvgScrMath',
           'AvgScrSci',
           'NumGE21',
           'PctGE21']
act_2019_ca[columns] = act_2019_ca[columns].apply(pd.to_numeric, axis=1)

# %%
act_2019_ca.dtypes
# Out:
# RType          object
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead    float64
# AvgScrEng     float64
# AvgScrMath    float64
# AvgScrSci     float64
# NumGE21       float64
# PctGE21       float64
# dtype: object

# %% [markdown]
# ### Step 7. Rename Columns.

# %%
sat_2019_ca.rename(columns={
    'RType': 'record_type', 
    'CName': 'county_name', 
    'Enroll12': 'num_of_enrolled', 
    'NumTSTTakr12': 'num_of_test_taker', 
    'NumERWBenchmark12': 'num_erw_met_benchmark',
    'PctERWBenchmark12': 'pct_erw_met_benchmark', 
    'NumMathBenchmark12': 'num_math_met_benchmark', 
    'PctMathBenchmark12': 'pct_math_met_benchmark',
    'TotNumBothBenchmark12': 'num_both_met_benchmark', 
    'PctBothBenchmark12': 'pct_both_met_benchmark'
}, inplace=True)

# %%
act_2019_ca.rename(columns={
    'RType': 'record_type', 
    'CName': 'county_name', 
    'Enroll12': 'num_of_enrolled', 
    'NumTstTakr': 'num_of_test_taker', 
    'AvgScrRead': 'avg_reading_score',
    'AvgScrEng': 'avg_english_score', 
    'AvgScrMath': 'avg_math_score', 
    'AvgScrSci': 'avg_science_socre',
    'NumGE21': 'num_students_score_>=21', 
    'PctGE21': 'pct_students_score_>=21'
}, inplace=True)

# %%
crime.rename(columns={
    'County': 'county_name',
    'Population': 'population',
    'Violent': 'violent',
    'Murder': 'murder',
    'Rape': 'rape',
    'Robbery': 'robbery',
    'Aggrevated assault': 'aggrevated_assault',
    'Property': 'property',
    'Burglary': 'burglary',
    'Vehicle theft': 'vehicle_theft',
    'Larceny theft': 'larceny_theft'
}, inplace=True)

# %%
poverty.rename(columns={
    'county': 'county_name'
}, inplace=True)

# %% [markdown]
# ### Step 8. Drop unnecessary rows (if needed).

# %%
###Done in step4

# %% [markdown]
# ### Step 9. Merge dataframes that can be merged.

# %%
###Not required

# %% [markdown]
# ### Step 10. Perform any additional cleaning that you feel is necessary.

# %%
###KIV

# %% [markdown]
# ### Step 11. Save your cleaned and merged dataframes as csv files.

# %%
#save df as csv
sat_2019_ca.to_csv('../data/sat_2019_sat_cleaned.csv', index=False)
act_2019_ca.to_csv('../data/sat_2019_act_cleaned.csv', index=False)
crime.to_csv('../data/crime_cleaned.csv', index=False)
poverty.to_csv('../data/poverty_cleaned.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# Dataframe: `sat_2019_ca`
#
# |Feature                  |Type    |Dataset     |Description|
# |-------------------------|--------|------------|-----------------------------------------------------|
# |**record_type**              |*object*  |sat_2019_ca | Record Type: C=County, D=District, S=School, X=State|
# |**county_name**              |*object*  |sat_2019_ca | County Name|
# |**num_of_enrolled**          |*float*   |sat_2019_ca | Enrollment of Grade 12|
# |**num_of_test_taker**        |*float*   |sat_2019_ca | Number of Test Takers Grade 12|
# |**num_erw_met_benchmark**    |*float*   |sat_2019_ca | The number meeting the Evidence-Based Reading & Writing (ERW) benchmark established by the College Board based on the New 2016 SAT test format as of March 2016 for Grade 12.|
# |**pct_erw_met_benchmark**    |*float*   |sat_2019_ca | The percent of students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW) test for Grade 12. |
# |**num_math_met_benchmark**   |*float*   |sat_2019_ca | The number of students who met or exceeded the benchmark for the New SAT Math test format as of March 2016 for Grade 12. |
# |**pct_math_met_benchmark**   |*float*   |sat_2019_ca | The percent of students who met or exceeded the benchmark for SAT Math test for Grade 12.|
# |**num_both_met_benchmark**   |*float*   |sat_2019_ca | The total number of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math Grade 12.|
# |**num_both_met_benchmark**   |*float*   |sat_2019_ca | The percent of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math Grade 12.|
#
#
#
# Dataframe: `act_2019_ca`
#
#
# |Feature                    |Type       |Dataset     |Description|
# |---------------------------|-----------|------------|-----------|
# |**record_type**            |*object*   |act_2019_ca | Record Type: C=County, D=District, S=School, X=State |
# |**county_name**            |*object*   |act_2019_ca | County Name |
# |**num_of_enrolled**        |*float*    |act_2019_ca | Enrollment of Grade 12 |
# |**num_of_test_taker**      |*float*    |act_2019_ca | Number of Test Takers Grade 12 |
# |**avg_reading_score**      |*float*    |act_2019_ca | The average reading score was calculated by dividing the sum of the students' reading ACT scores by the "Number Tested." |
# |**avg_english_score**      |*float*    |act_2019_ca | The average English score was calculated by dividing the sum of the students' English ACT scores by the "Number Tested." |
# |**avg_math_score**         |*float*    |act_2019_ca | The average math score was calculated by dividing the sum of the students' math ACT scores by the "Number Tested." |
# |**avg_science_socre**      |*float*    |act_2019_ca | The average science score was calculated by dividing the sum of the students' science ACT scores by the "Number Tested." |
# |**num_students_score_>=21**|*float*    |act_2019_ca | This was the number of students who scored 21 points or more on the composite score. The composite score was taken from the data file received from ACT, Inc. |
# |**pct_students_score_>=21**|*float*    |act_2019_ca | This item identifies the percent of students who scored 21 points or more on the composite score by dividing the "Number of Scores >= 21" by the "Number Tested." |
#
#
# Dataframe: `crime`
#
# |Feature        |Type    |Dataset|Description|
# |---------------|--------|------|-----------|
# |**county_name**|*object*|crime | County Name |
# |**population** |*float* |crime | Population number |
# |**violent**    |*float* |crime | Number of violent per 100,000 residents    |
# |**murder**     |*float* |crime | Number of murder per 100,000 residents     |
# |**rape**       |*float* |crime | Number of rape per 100,000 residents       |
# |**robbery**    |*float* |crime | Number of robbery per 100,000 residents    |
# |**aggrevated** |*float* |crime | Number of aggrevated per 100,000 residents |
# |**property**   |*float* |crime | Number of property per 100,000 residents   |
# |**burglary**   |*float* |crime | Number of burglary per 100,000 residents   |
# |**vehicle**    |*float* |crime | Number of vehicle per 100,000 residents    |
# |**larceny**    |*float* |crime | Number of larceny per 100,000 residents    |
#
# Dataframe: `poverty`
#
# |Feature                      |Type     |Dataset|Description|
# |-----------------------------|---------|-------|------------|
# |**county**                   |*object* |poverty| County Name|
# |**poverty_rate**             |*float*  |poverty| Official poverty rate calculated using the official poverty universe and definition of poverty units.|
# |**rate_margin_of_error(%)**  |*float*  |poverty| Rate margin of error (% pt)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# #### Step 1: Summary Statistics

# %%
sat_2019_ca.describe()
# Out:
#        num_of_enrolled  num_of_test_taker  num_erw_met_benchmark  \
# count        55.000000          55.000000              55.000000
# mean       8899.509091        3098.054545            2117.927273
# std       17703.521422        7238.653654            4612.155846
# min          87.000000          16.000000              12.000000
# 25%         677.500000         138.000000             103.000000
# 50%        2551.000000         630.000000             547.000000
# 75%        8314.500000        2743.000000            2021.500000
# max      114618.000000       48676.000000           30081.000000
#
#        pct_erw_met_benchmark  num_math_met_benchmark  pct_math_met_benchmark  \
# count              55.000000               55.000000               55.000000
# mean               74.402545             1482.545455               52.194727
# std                 9.793826             3131.258301               13.101901
# ...

# %%
act_2019_ca.describe()
# Out:
#        num_of_enrolled  num_of_test_taker  avg_reading_score  \
# count        58.000000          58.000000          54.000000
# mean       8442.241379        1425.310345          22.648148
# std       17344.164490        3164.257498           2.466052
# min           0.000000           0.000000          17.000000
# 25%         525.500000          64.250000          21.000000
# 50%        2325.500000         365.000000          23.000000
# 75%        7477.250000        1212.250000          25.000000
# max      114618.000000       20678.000000          27.000000
#
#        avg_english_score  avg_math_score  avg_science_socre  \
# count          54.000000       54.000000          54.000000
# mean           21.537037       21.814815          21.722222
# std             2.589623        2.137483           2.041241
# min            15.000000       17.000000          18.000000
# 25%            20.000000       20.000000          20.000000
# ...

# %%
crime.describe()
# Out:
#          population      violent     murder        rape     robbery  \
# count  5.800000e+01    58.000000  58.000000   58.000000   58.000000
# mean   6.844030e+05   418.412579   3.829737   47.428466   76.029378
# std    1.483803e+06   185.972098   3.000956   29.184103   64.778105
# min    1.149000e+03    31.152648   0.000000    0.000000    0.000000
# 25%    4.744675e+04   310.556596   1.832329   30.776115   35.940627
# 50%    1.894195e+05   403.745378   3.396572   41.548174   62.724497
# 75%    7.126715e+05   503.521734   4.958952   51.291027   90.000227
# max    1.018438e+07  1131.418625  14.665982  174.064404  356.108330
#
#        aggrevated_assault     property     burglary  vehicle_theft  \
# count           58.000000    58.000000    58.000000      58.000000
# mean           291.124998  2064.023226   447.374825     277.444249
# std            160.727261   797.768963   185.211768     150.961776
# min             31.152648   684.860434   156.064572       0.000000
# ...

# %%
poverty.describe()
# Out:
#        poverty_rate  rate_margin_of_error(%)
# count     58.000000                58.000000
# mean       0.131436                 2.115801
# std        0.043440                 1.067410
# min        0.052242                 0.344860
# 25%        0.106615                 1.318233
# 50%        0.125340                 2.230296
# 75%        0.162725                 2.612498
# max        0.235754                 4.992496

# %% [markdown]
# #### Step 2: Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.

# %%
#standard deviation of numeric data for sat_2019_ca dataframe using dictionary comprehension 
sd_sat_2019_ca = {column: std_dev(sat_2019_ca[column]) for column in sat_2019_ca 
                  if sat_2019_ca[column].dtypes==float}

# %%
sd_sat_2019_ca
# Out:
# {'num_of_enrolled': 17541.84204059511,
#  'num_of_test_taker': 7172.54584298714,
#  'num_erw_met_benchmark': 4570.034819260811,
#  'pct_erw_met_benchmark': 9.704383118080164,
#  'num_math_met_benchmark': 3102.6617359831353,
#  'pct_math_met_benchmark': 12.982246178327953,
#  'num_both_met_benchmark': 2922.878916806861,
#  'pct_both_met_benchmark': 13.132079648739055}

# %%
#standard deviation of numeric data for act_2019_ca dataframe using dictionary comprehension 
sd_act_2019_ca = {column: std_dev(act_2019_ca[column]) for column in act_2019_ca
                  if act_2019_ca[column].dtypes == float}

# %%
sd_act_2019_ca
# Out:
# {'num_of_enrolled': 17193.99573759673,
#  'num_of_test_taker': 3136.860813895805,
#  'avg_reading_score': nan,
#  'avg_english_score': nan,
#  'avg_math_score': nan,
#  'avg_science_socre': nan,
#  'num_students_score_>=21': nan,
#  'pct_students_score_>=21': nan}

# %%
#standard deviation of numeric data for crime dataframe using dictionary comprehension 
sd_crime = {column: std_dev(crime[column]) for column in crime 
            if crime[column].dtypes == float}

# %%
sd_crime
# Out:
# {'population': 1470955.9087166572,
#  'violent': 184.3619199451459,
#  'murder': 2.974973683313454,
#  'rape': 28.931421570440865,
#  'robbery': 64.21724550733192,
#  'aggrevated_assault': 159.3356572810606,
#  'property': 790.8617419301319,
#  'burglary': 183.60817290101502,
#  'vehicle_theft': 149.6547232300687,
#  'larceny_theft': 630.7601744953387}

# %%
#standard deviation of numeric data for poverty dataframe using dictionary comprehension 
sd_poverty = {column: std_dev(poverty[column]) for column in poverty 
              if poverty[column].dtypes == float}

# %%
sd_poverty
# Out:
# {'poverty_rate': 0.04306405271549273,
#  'rate_margin_of_error(%)': 1.0581680954612254}

# %% [markdown]
# #### Step 3: Investigate trends in the data
#
# - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#     - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#     - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#     - Do any states with 100% participation on a given test have a rate change year-to-year?
#     - Do any states show have >50% participation on *both* tests each year?
#     - Which colleges have the highest median SAT and ACT scores for admittance?
#     - Which California school districts have the highest and lowest mean test scores?
# - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Investigate which counties have the lower % of students whom met the benchmark for both ERW and Math (SAT)
sat_2019_ca.sort_values('pct_both_met_benchmark')[['county_name',
                                                   'pct_both_met_benchmark']].head()
# Out:
#    county_name  pct_both_met_benchmark
# 46      Colusa                   18.92
# 20       Glenn                   27.78
# 2       Madera                   28.73
# 33      Merced                   29.12
# 47        Inyo                   31.82

# %%
#Investigate which counties have the higher % of students whom met the benchmark for both ERW and Math (SAT)
sat_2019_ca.sort_values('pct_both_met_benchmark', ascending=False)[['county_name',
                                                                    'pct_both_met_benchmark']].head()
# Out:
#    county_name  pct_both_met_benchmark
# 0    El Dorado                   73.18
# 11    Mariposa                   72.22
# 12      Placer                   68.91
# 18       Marin                   68.81
# 29      Nevada                   68.28

# %%
#Investigate which counties have the lower % of students whom score >= 21 for ACT
act_2019_ca.sort_values('pct_students_score_>=21')[['county_name',
                                                    'pct_students_score_>=21']].head()
# Out:
#        county_name  pct_students_score_>=21
# 30           Modoc                    20.00
# 16           Kings                    24.47
# 37  San Bernardino                    28.61
# 55          Merced                    30.30
# 19          Madera                    33.33

# %%
#Investigate which counties have the higher % of students whom score >= 21 for ACT
act_2019_ca.sort_values('pct_students_score_>=21', ascending=False)[['county_name',
                                                                     'pct_students_score_>=21']].head()
# Out:
#    county_name  pct_students_score_>=21
# 5    Calaveras                    87.10
# 8        Marin                    80.48
# 6         Mono                    80.00
# 27      Amador                    78.38
# 31    Tuolumne                    78.26

# %%
crime.head()
# Out:
#   county_name  population      violent    murder        rape     robbery  \
# 0     Alameda   1664783.0   584.700829  5.766517   42.167658  295.293741
# 1      Alpine      1149.0  1131.418625  0.000000  174.064404    0.000000
# 2      Amador     37820.0   290.851401  2.644104   21.152829   23.796933
# 3       Butte    221521.0   462.258657  3.159971   81.256405   75.387886
# 4   Calaveras     45085.0   321.614728  2.218033   75.413109   19.962293
#
#    aggrevated_assault     property     burglary  vehicle_theft  larceny_theft
# 0          241.472913  4008.390283   391.402363     616.717014    3000.270906
# 1          957.354221  2785.030461  1131.418625     348.128808    1305.483029
# 2          243.257536  1771.549445   470.650449      97.831835    1203.067160
# 3          302.454395  2402.481029   501.532586     391.836440    1509.112003
# 4          224.021293  1858.711323   658.755684     153.044250    1046.911390

# %%
sns.pairplot(crime, corner=True)

# %%
plt.figure(figsize=(16,12))
sns.heatmap(test.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(test, corner=True)

# %%
sat_2019_ca.county_name.nunique()
# Out:
# 55

# %%
crime.county_name.nunique()
# Out:
# 58

# %%
test = pd.merge(left=act_2019_ca,
        right=sat_2019_ca,
        on='county_name')

# %%
poverty.plot(kind='bar',x='county_name',y='poverty_rate', figsize=(15,7), grid=True)

# %%
sat_2019_ca.sort_values('pct_both_met_benchmark',ascending=False).plot(kind='bar',x='county_name',y='pct_both_met_benchmark', figsize=(15,7), grid=True)

# %%
sat_2019_ca.head()

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
